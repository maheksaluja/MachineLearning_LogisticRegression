# %%
import os
import pandas as pd
import numpy as np



Root_Data_Dir = '../data/AReM'
Col = ['avg_rss12', 'var_rss12', 'avg_rss13', 'var_rss13', 'avg_rss23', 'var_rss23']
all_file_path = []
for root, dirs, files in os.walk(Root_Data_Dir):
    for file in files:
        if not file.startswith('.'):
            all_file_path.append(os.path.join(root, file))
all_file_path.sort()
dir_list = os.listdir(Root_Data_Dir)
dir_list.sort()
test_files = []
path = Root_Data_Dir + '/'
for i, dir in enumerate(dir_list):
    if not dir.startswith('.'):
        test_files.append(Root_Data_Dir + '/' + dir + '/dataset1.csv')
        test_files.append(Root_Data_Dir + '/' + dir + '/dataset2.csv')
        if dir != 'bending1' and dir != 'bending2':
            test_files.append(Root_Data_Dir + '/' + dir + '/dataset3.csv')

train_files = list(set(all_file_path) - set(test_files))
train_files.sort()

#train_files
##Loading Train Data##

# %%
train_dataframe = pd.DataFrame()

for path in train_files:
    f = pd.read_csv(path, delimiter=',', skiprows = 5, names=Col)
    train_dataframe = train_dataframe.append(f)
train_dataframe
# Out:
#         avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0           42.00       0.71      21.25       0.43      30.00       0.00
# 250         41.50       0.50      20.25       1.48      31.25       1.09
# 500         41.50       0.50      14.25       1.92      33.00       0.00
# 750         40.75       0.83      15.75       0.43      33.00       0.00
# 1000        40.00       0.71      20.00       2.74      32.75       0.43
# ...           ...        ...        ...        ...        ...        ...
# 118750      31.50       1.66      12.50       3.20      14.25       4.44
# 119000      27.33       1.25      11.33       0.94      20.00       4.00
# 119250      37.80       7.68      14.20       2.48      17.25       0.83
# 119500      33.75       1.30      15.75       5.21      16.50       2.69
# 119750      32.67       3.09      18.67       0.47      14.00       3.16
#
# [33119 rows x 6 columns]

# %%
test_dataframe = pd.DataFrame()

for path in test_files:
    f = pd.read_csv(path, delimiter=',', skiprows = 5, names=Col)
    test_dataframe = test_dataframe.append(f)
test_dataframe
# Out:
#         avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0           39.25       0.43      22.75       0.43      33.75       1.30
# 250         39.25       0.43      23.00       0.00      33.00       0.00
# 500         39.25       0.43      23.25       0.43      33.00       0.00
# 750         39.50       0.50      23.00       0.71      33.00       0.00
# 1000        39.50       0.50      24.00       0.00      33.00       0.00
# ...           ...        ...        ...        ...        ...        ...
# 118750      36.00       2.45      17.00       5.10      20.50       0.87
# 119000      34.33       1.89      15.00       2.45      17.00       2.12
# 119250      33.00       7.35      14.60       3.14      13.00       5.70
# 119500      31.67       1.25      11.00       6.16      19.25       2.17
# 119750      30.75      10.21      11.75       1.09      18.50       3.20
#
# [9120 rows x 6 columns]

# %%
# feature_dataframe = pd.DataFrame()

feature_data = []
for i, path in enumerate(all_file_path):
    temp = path.split('/')
    label = temp[-2] + "/" + temp[-1]
    f =pd.read_csv(path, delimiter=',', skiprows = 5, names=Col)
    data = []
    for j, col in enumerate(f.columns):
        temp = [f[col].min(), f[col].max(), f[col].mean(), f[col].median(), f[col].std(), f[col].quantile(.25), f[col].quantile(.75)]
        data.extend(temp)
    feature_data.append(data)
feature_dataframe = pd.DataFrame(feature_data)
feature_dataframe.columns = ['min(1)', 'max(1)', 'mean(1)', 'median(1)', 'std(1)', 'firstquartile(1)', 'thirdquartie(1)',
                            'min(2)', 'max(2)', 'mean(2)', 'median(2)', 'std(2)', 'firstquartile(2)', 'thirdquartie(2)',
                            'min(3)', 'max(3)', 'mean(3)', 'median(3)', 'std(3)', 'firstquartile(3)', 'thirdquartie(3)',
                            'min(4)', 'max(4)', 'mean(4)', 'median(4)', 'std(4)', 'firstquartile(4)', 'thirdquartie(4)',
                            'min(5)', 'max(5)', 'mean(5)', 'median(5)', 'std(5)', 'firstquartile(5)', 'thirdquartie(5)',
                            'min(6)', 'max(6)', 'mean(6)', 'median(6)', 'std(6)', 'firstquartile(6)', 'thirdquartie(6)']
feature_dataframe
# Out:
#     min(1)  max(1)    mean(1)  median(1)    std(1)  firstquartile(1)  \
# 0    37.25   45.00  40.624792     40.500  1.476967             39.25
# 1    38.00   45.67  42.812812     42.500  1.435550             42.00
# 2    35.00   47.40  43.954500     44.330  1.558835             43.00
# 3    33.00   47.75  42.179813     43.500  3.670666             39.15
# 4    33.00   45.75  41.678063     41.750  2.243490             41.33
# ..     ...     ...        ...        ...       ...               ...
# 83   20.75   46.25  34.763333     35.290  4.742208             31.67
# 84   21.50   51.00  34.935813     35.500  4.645944             32.00
# 85   18.33   47.67  34.333042     34.750  4.948770             31.25
# 86   18.33   45.75  34.599875     35.125  4.731790             31.50
# 87   15.50   43.67  34.225875     34.750  4.441798             31.25
#
#     thirdquartie(1)  min(2)  max(2)   mean(2)  ...    std(5)  \
# 0           42.0000     0.0    1.30  0.358604  ...  2.188449
# 1           43.6700     0.0    1.22  0.372438  ...  1.995255
# 2           45.0000     0.0    1.70  0.426250  ...  1.999604
# 3           45.0000     0.0    3.00  0.696042  ...  3.849448
# 4           42.7500     0.0    2.83  0.535979  ...  2.411026
# ..              ...     ...     ...       ...  ...       ...
# 83          38.2500     0.0   12.68  4.223792  ...  3.174681
# 84          38.0625     0.0   12.21  4.115750  ...  3.192058
# 85          38.0000     0.0   12.48  4.396958  ...  3.000493
# 86          38.0000     0.0   15.37  4.398833  ...  2.905688
# 87          37.2500     0.0   17.24  4.354500  ...  2.992920
#
#     firstquartile(5)  thirdquartie(5)  min(6)  max(6)   mean(6)  median(6)  \
# 0            33.0000            36.00     0.0    1.92  0.570583      0.430
# 1            32.0000            34.50     0.0    3.11  0.571083      0.430
# 2            35.3625            36.50     0.0    1.79  0.493292      0.430
# 3            30.4575            36.33     0.0    2.18  0.613521      0.500
# 4            28.4575            31.25     0.0    1.79  0.383292      0.430
# ..               ...              ...     ...     ...       ...        ...
# 83           14.2500            18.33     0.0    9.39  3.288271      3.270
# 84           14.2375            18.25     0.0   10.21  3.280021      3.015
# 85           13.7500            18.00     0.0    8.01  3.261583      2.980
# 86           14.0000            18.25     0.0    8.86  3.289542      3.015
# 87           14.3300            18.25     0.0    9.42  3.479542      3.270
#
#       std(6)  firstquartile(6)  thirdquartie(6)
# 0   0.582915              0.00           1.3000
# 1   0.601010              0.00           1.3000
# 2   0.513506              0.00           0.9400
# 3   0.524317              0.00           1.0000
# 4   0.389164              0.00           0.5000
# ..       ...               ...              ...
# 83  1.647528              2.05           4.3050
# 84  1.700918              2.12           4.5000
# 85  1.617290              2.05           4.3200
# 86  1.680170              2.12           4.2600
# 87  1.761146              2.24           4.5375
#
# [88 rows x 42 columns]

# %%
for col in feature_dataframe.columns:
    print(col)
    print(feature_dataframe[col].std())
    print("\n")
# Out:
# min(1)
# 9.569975284512807
#
#
# max(1)
# 4.394361684703192
#
#
# mean(1)
# 5.3357176583441746
#
#
# median(1)
# 5.440054137152637
#
#
# std(1)
# 1.772153397502841
#
#
# firstquartile(1)
# 6.153589724185372
#
#
# thirdquartie(1)
# 5.1389246134510005
#
#
# min(2)
# 0.0
#
#
# max(2)
# 5.06272937481064
#
#
# mean(2)
# 1.5741639200745123
#
#
# median(2)
# 1.4122441649745636
#
#
# std(2)
# 0.8841054781862712
#
#
# firstquartile(2)
# 0.9463861911256924
#
#
# thirdquartie(2)
# 2.12526640640591
#
#
# min(3)
# 2.9564620592058177
#
#
# max(3)
# 4.875136693954744
#
#
# mean(3)
# 4.008380131777649
#
#
# median(3)
# 4.036396318784073
#
#
# std(3)
# 0.9467102620752956
#
#
# firstquartile(3)
# 4.22065788450763
#
#
# thirdquartie(3)
# 4.171628224016797
#
#
# min(4)
# 0.0
#
#
# max(4)
# 2.183625484972341
#
#
# mean(4)
# 1.1661140909196097
#
#
# median(4)
# 1.1455856609880564
#
#
# std(4)
# 0.45824169747631166
#
#
# firstquartile(4)
# 0.8436196840035469
#
#
# thirdquartie(4)
# 1.5525041782503672
#
#
# min(5)
# 6.124001430553485
#
#
# max(5)
# 5.7412383009519505
#
#
# mean(5)
# 5.675593204313177
#
#
# median(5)
# 5.813782436530038
#
#
# std(5)
# 1.0248979053506881
#
#
# firstquartile(5)
# 6.09646520156495
#
#
# thirdquartie(5)
# 5.531720219299493
#
#
# min(6)
# 0.04583815401645624
#
#
# max(6)
# 2.518920977690553
#
#
# mean(6)
# 1.154811923954455
#
#
# median(6)
# 1.0864743253475886
#
#
# std(6)
# 0.5176174745904131
#
#
# firstquartile(6)
# 0.7585838153286205
#
#
# thirdquartie(6)
# 1.5235991261756407

# %%
CI = {}
for col in feature_dataframe.columns:
    CI_Range = []
    for i  in range(1000):
        sample = feature_dataframe[col].sample(n =88, replace = True)
#         print(len(sample))
        CI_Range.append(sample.std())
    CI_Range.sort()
    lower_value = np.percentile(CI_Range, 5)
    upper_value = np.percentile(CI_Range, 95)
    CI[col] = (lower_value, upper_value,feature_dataframe[col].std() )
    

pd.DataFrame(CI)

#feature_dataframe['min(1)'].sample(frac = 1, replace=True)
# Out:
#       min(1)    max(1)   mean(1)  median(1)    std(1)  firstquartile(1)  \
# 0   8.275396  3.337571  4.697466   4.835278  1.569927          5.541276
# 1  10.836696  5.257787  5.850508   5.992522  1.954354          6.647806
# 2   9.569975  4.394362  5.335718   5.440054  1.772153          6.153590
#
#    thirdquartie(1)  min(2)    max(2)   mean(2)  ...    std(5)  \
# 0         4.327083     0.0  4.655182  1.399154  ...  0.819493
# 1         5.875883     0.0  5.385785  1.702877  ...  1.211463
# 2         5.138925     0.0  5.062729  1.574164  ...  1.024898
#
#    firstquartile(5)  thirdquartie(5)    min(6)    max(6)   mean(6)  median(6)  \
# 0          4.734691         4.363406  0.000000  2.249897  1.062732   0.995112
# 1          7.118269         6.514424  0.078476  2.758770  1.211013   1.148300
# 2          6.096465         5.531720  0.045838  2.518921  1.154812   1.086474
#
#      std(6)  firstquartile(6)  thirdquartie(6)
# 0  0.477426          0.689841         1.400479
# 1  0.545919          0.808447         1.602262
# 2  0.517617          0.758584         1.523599
#
# [3 rows x 42 columns]

# %%
cols = ['std(1)', 'max(1)', 'mean(1)', 'std(2)', 'max(2)', 'mean(2)', 'std(6)', 'max(6)', 'mean(6)', 'label']
time_series_list = [1,2,6]
feature_data = []
for i, path in enumerate(train_files):
    temp = path.split('/')
    l = 0
    if 'bending' in temp[-2]:
        l=1
    label = temp[-2] + "/" + temp[-1]
    f =pd.read_csv(path, delimiter=',', skiprows = 5, names=Col)
    data = []
    for j, col in enumerate(f.columns):
        if j+1 in time_series_list:
            temp = [f[col].std(), f[col].max(), f[col].mean()]
            data.extend(temp)
    data.extend([int(l)])
    feature_data.append(data)
feature_dataframe = pd.DataFrame(feature_data)
feature_dataframe.columns = cols
feature_dataframe
# Out:
#       std(1)  max(1)    mean(1)    std(2)  max(2)   mean(2)    std(6)  max(6)  \
# 0   1.558835   47.40  43.954500  0.338690    1.70  0.426250  0.513506    1.79
# 1   3.670666   47.75  42.179813  0.630860    3.00  0.696042  0.524317    2.18
# 2   2.243490   45.75  41.678063  0.405469    2.83  0.535979  0.389164    1.79
# 3   1.386098   48.00  43.454958  0.315566    1.58  0.378083  0.622534    5.26
# 4   1.618364   48.00  43.969125  0.263111    1.50  0.413125  0.487826    2.96
# ..       ...     ...        ...       ...     ...       ...       ...     ...
# 64  4.742208   46.25  34.763333  2.278004   12.68  4.223792  1.647528    9.39
# 65  4.645944   51.00  34.935813  2.335243   12.21  4.115750  1.700918   10.21
# 66  4.948770   47.67  34.333042  2.568680   12.48  4.396958  1.617290    8.01
# 67  4.731790   45.75  34.599875  2.538521   15.37  4.398833  1.680170    8.86
# 68  4.441798   43.67  34.225875  2.518991   17.24  4.354500  1.761146    9.42
#
#      mean(6)  label
# 0   0.493292      1
# 1   0.613521      1
# 2   0.383292      1
# 3   0.679646      1
# 4   0.555313      1
# ..       ...    ...
# 64  3.288271      0
# 65  3.280021      0
# 66  3.261583      0
# 67  3.289542      0
# 68  3.479542      0
#
# [69 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#plt.scatter(feature_dataframe[:9], feature_dataframe['label'])
sns.pairplot(feature_dataframe, kind='scatter', hue = 'label')

# %%
cols = ['std(1)', 'max(1)', 'mean(1)', 'std(2)', 'max(2)', 'mean(2)', 'std(12)', 'max(12)', 'mean(12)', 'label']
time_series_list = [1,2,12]
feature_data = []
for i, path in enumerate(train_files):
    
    temp = path.split('/')
    l = 0
    if 'bending' in temp[-2]:
        l=1
    
    
    label = temp[-2] + "/" + temp[-1]
    
    f =pd.read_csv(path, delimiter=',', skiprows = 5, names=Col)
    np_arr = f.to_numpy()
    half = len(f)/2
    split_temp = [np_arr[round(half * i): round(half *(i+1))] for i in range(2)]
    new_f = pd.concat([pd.DataFrame(split_temp[0]), pd.DataFrame(split_temp[0])], sort=False, axis = 1)
    new_f.columns = [str(col) + "_" + str(i)  for i in range(1,3) for col in Col]
    
    
    data = []
    for j, col in enumerate(new_f.columns):
        if j+1 in time_series_list:
            temp_d = [new_f[col].std(), new_f[col].max(), new_f[col].mean()]
            data.extend(temp_d)
    data.extend([int(l)])
    feature_data.append(data)
feature_dataframe = pd.DataFrame(feature_data)
feature_dataframe.columns = cols
feature_dataframe
# Out:
#       std(1)  max(1)    mean(1)    std(2)  max(2)   mean(2)   std(12)  \
# 0   1.556971   46.50  44.057167  0.329540    1.50  0.381042  0.526656
# 1   3.473355   47.75  43.278875  0.634285    3.00  0.673292  0.554542
# 2   3.118644   45.75  41.621208  0.489595    2.83  0.623083  0.411200
# 3   1.359836   48.00  44.117042  0.314099    1.30  0.250042  0.718016
# 4   1.281976   45.00  43.486208  0.284434    1.30  0.378667  0.486847
# ..       ...     ...        ...       ...     ...       ...       ...
# 64  4.733014   46.00  34.966250  2.331940   12.68  4.207958  1.638218
# 65  4.276717   45.67  34.737042  2.337759   12.21  4.217333  1.737573
# 66  5.143776   45.00  33.886458  2.453111   12.44  4.332208  1.565557
# 67  4.869092   44.00  34.836458  2.512633   12.38  4.257750  1.647640
# 68  4.549837   42.75  34.329333  2.470266   14.50  4.315917  1.725690
#
#     max(12)  mean(12)  label
# 0      1.79  0.598250      1
# 1      1.53  0.640958      1
# 2      1.79  0.419083      1
# 3      5.26  0.815417      1
# 4      2.28  0.524875      1
# ..      ...       ...    ...
# 64     8.83  3.146333      0
# 65     9.19  3.334125      0
# 66     7.89  3.248417      0
# 67     8.86  3.169625      0
# 68     9.42  3.381250      0
#
# [69 rows x 10 columns]

# %%
sns.pairplot(feature_dataframe, kind='scatter', hue = 'label')

# %%
import statsmodels.api as sm
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFECV
from statsmodels.discrete.discrete_model import Logit
from sklearn.model_selection import cross_val_score
import statsmodels.api as sm

def split_data(parts, file):
    p = len(file)/parts
    np_arr = file.to_numpy()
    split_temp = [np_arr[round(p * i): round(p *(i+1))] for i in range(parts)]
    res = pd.DataFrame()
    for df in split_temp:
        res = pd.concat([res, pd.DataFrame(df)], sort = False, axis = 1)
    temp_lbl = [i for i in range(1, 6*parts+1)]
    res.columns = temp_lbl
    return res

def stats(df):
    row = []
    for i, col in enumerate(df.columns):
        temp = [df[col].std(), df[col].max(), df[col].mean()]
        row.extend(temp)
    #print(row)
    return row

# %%
tmp_lbl = [i for i in range(1, 37)]
split_score_track = {}
for l in range(1,21):
    #print(l)
    final_df = pd.DataFrame()
    labels=[]
    for index, path in enumerate(train_files):
        file = pd.read_csv(path, delimiter=',', skiprows = 5, names=Col)
        temp_dir = path.split('/')[-2]
        label = 0
        if 'bending' in temp_dir:
            label = 1
        df = split_data(l,file)
#         print(len(df_list))
        temp = []
        stat_row = stats(df)
        temp.append(stat_row)
        labels.append(label)
# 
        final_df = final_df.append(pd.DataFrame(temp))
    
    logreg = LogisticRegression(C=1000000000, solver='lbfgs')
    rfecv = RFECV(logreg, cv=5)
    np_arr = final_df.to_numpy()
    selector = rfecv.fit(np_arr, labels)
#     logit = sm.Logit(labels, np_arr)
#     print(logit.fit(method = 'bfgs').summary)
    split_score_track[l] = [selector.support_, sum(selector.support_), max(selector.grid_scores_), selector.score(np_arr, labels)]
    #scores = cross_val_score(logreg, np_arr, labels, cv = 2)
    #print(scores)
    #print((scores.mean(), scores.std() * 2))


split_score_track
# Out:
# {1: [array([False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True, False, False, False, False]),
#   1,
#   0.9857142857142858,
#   0.9710144927536232],
#  2: [array([False,  True, False, False, False, False, False, False, False,
#          False, False, False, False,  True,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False, False, False]),
#   4,
#   1.0,
#   1.0],
#  3: [array([False,  True, False, False,  True, False, False, False,  True,
#          False, False, False, False,  True,  True, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False,  True,  True, False, False, False,
#          False, False,  True, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False,  True, False]),
#   11,
#   0.9857142857142858,
#   1.0],
#  4: [array([False,  True, False, False, False, False, False, False, False,
#          False, False, False, False,  True,  True, False, False, False,
#          False, False, False, False, False, False, False, False,  True,
#          False, False, False, False, False,  True, False,  True, False,
#          False, False,  True, False, False, False, False, False, False,
#          False, False, False, False, False, False, False,  True, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False,  True, False]),
#   10,
#   1.0,
#   1.0],
#  5: [array([False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False]),
#   2,
#   0.9714285714285715,
#   0.9565217391304348],
#  6: [array([False, False, False, False, False, False, False, False,  True,
#          False, False, False, False,  True,  True, False, False, False,
#          False, False, False, False,  True, False, False, False, False,
#          False, False, False, False,  True,  True, False,  True, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True,  True, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False,  True, False]),
#   10,
#   0.9714285714285715,
#   1.0],
#  7: [array([False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False,  True, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True,  True, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False,  True, False]),
#   10,
#   0.9857142857142858,
#   1.0],
#  8: [array([False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False]),
#   3,
#   0.9857142857142858,
#   1.0],
#  9: [array([False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False,  True, False]),
#   6,
#   0.9857142857142858,
#   1.0],
#  10: [array([False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True,  True, False, False, False,
#          False, False, False, False, False, False, False, False,  True,
#          False, False, False, False,  True,  True, False, False, False,
#          False, False, False, False,  True, False, False, False, False,
#          False, False, False, False,  True,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False,  True, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False, False, False,
#          False,  True,  True, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True,  True, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False,  True,
#          False, False, False, False, False,  True, False,  True, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False, False, False]),
#   21,
#   0.9714285714285715,
#   1.0],
#  11: [array([False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False,  True, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False,  True, False,
#          False, False, False, False, False,  True, False,  True, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False]),
#   10,
#   0.9714285714285715,
#   1.0],
#  12: [array([False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False,  True, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False,  True, False,
#          False, False, False, False, False,  True, False,  True, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False]),
#   15,
#   0.9857142857142858,
#   1.0],
#  13: [array([False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False,  True, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False]),
#   8,
#   0.9857142857142858,
#   1.0],
#  14: [array([False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False,  True, False,
#          False, False, False, False, False,  True, False,  True, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False]),
#   15,
#   1.0,
#   1.0],
#  15: [array([False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True,  True, False, False, False,
#          False, False, False, False, False, False, False, False,  True,
#          False, False, False, False,  True,  True, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False,  True,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False,  True, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False, False, False,
#          False,  True,  True, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True,  True, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False,  True, False,
#          False, False, False, False, False,  True, False,  True, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False, False, False]),
#   22,
#   0.9857142857142858,
#   1.0],
#  16: [array([False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True,  True, False, False, False,
#          False, False, False, False, False, False, False, False,  True,
#          False, False, False, False,  True,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True,  True, False,  True, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False, False, False,
#          False,  True,  True, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False,  True,
#          False, False, False, False, False,  True, False, False, False,
#          False, False, False, False, False, False, False,  True, False,
#          False, False, False, False, False,  True, False,  True, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False, False, False]),
#   24,
#   1.0,
#   1.0],
#  17: [array([False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False,  True, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False]),
#   7,
#   0.9857142857142858,
#   1.0],
#  18: [array([False, False, False, False, False, False, False, False,  True,
#          False, False, False, False,  True,  True, False, False, False,
#          False, False, False, False, False, False, False, False,  True,
#          False, False, False, False,  True,  True, False, False, False,
#          False,  True, False, False, False, False,  True, False,  True,
#          False, False, False, False,  True,  True, False, False, False,
#          False, False, False, False, False, False, False, False,  True,
#          False, False, False,  True,  True,  True, False, False, False,
#          False,  True,  True, False,  True, False, False, False,  True,
#          False, False, False,  True,  True,  True, False,  True, False,
#           True,  True, False, False,  True, False, False,  True,  True,
#          False,  True, False,  True,  True,  True, False,  True, False,
#          False,  True,  True, False, False, False, False, False,  True,
#          False, False, False, False,  True,  True, False,  True, False,
#          False, False, False, False, False, False, False,  True,  True,
#          False, False, False, False,  True,  True, False,  True, False,
#          False,  True, False, False,  True, False, False, False, False,
#          False,  True, False, False,  True,  True, False,  True, False,
#           True,  True, False, False,  True, False, False, False, False,
#          False, False, False, False,  True,  True, False,  True, False,
#          False,  True,  True, False, False, False, False, False, False,
#          False, False, False, False,  True,  True, False, False, False,
#          False,  True,  True, False,  True, False, False,  True,  True,
#          False,  True, False, False,  True,  True, False,  True, False,
#          False,  True,  True, False,  True, False, False,  True,  True,
#          False,  True, False, False, False,  True, False,  True, False,
#          False,  True,  True, False,  True, False, False, False,  True,
#          False, False, False, False, False,  True, False,  True, False,
#          False,  True,  True, False,  True, False, False, False, False,
#          False, False, False, False,  True,  True, False, False, False,
#          False, False,  True, False, False, False, False,  True,  True,
#          False, False, False,  True,  True,  True, False,  True, False,
#          False,  True, False, False, False, False, False,  True,  True,
#          False,  True, False,  True,  True,  True, False,  True, False,
#          False,  True,  True, False, False, False, False, False, False,
#          False, False, False, False,  True,  True, False, False, False]),
#   107,
#   0.9857142857142858,
#   1.0],
#  19: [array([False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False,  True, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False]),
#   9,
#   0.9714285714285715,
#   1.0],
#  20: [array([False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True,  True, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False,  True, False,  True, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False,  True,  True, False, False, False,
#          False,  True,  True, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False,  True,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False,  True, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False,  True,  True,
#          False, False, False, False, False,  True, False,  True, False,
#          False, False, False, False, False, False, False,  True, False,
#          False, False, False, False, False,  True, False,  True, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False]),
#   30,
#   0.9857142857142858,
#   1.0]}

# %%
list_score = [split_score_track[x][2] for x in range(1, 21)]
index = np.argmax(list_score)+1

##BEST (l,p)

(index, split_score_track[index][1])
#print(list_score)
# Out:
# (2, 4)

# %%
from sklearn.metrics import confusion_matrix



best_feature = [i for i, val in enumerate(split_score_track[int(index)][0]) if val]
print(best_feature)
best_l = index
final_df = pd.DataFrame()

labels_train=[]
for ind, path in enumerate(train_files):
    file = pd.read_csv(path, delimiter=',', skiprows = 5, names=Col)
    temp_dir = path.split('/')[-2]
    label = 0
    if 'bending' in temp_dir:
        label = 1
    df = split_data(int(best_l),file)
#   print(len(df_list))
    temp = []
    stat_row = stats(df)
    temp.append(stat_row)
    labels_train.append(label) 
    final_df = final_df.append(pd.DataFrame(temp))
train_df = final_df[best_feature]
train_df


logreg = LogisticRegression(C=1000000000, solver='lbfgs')
#rfecv = RFECV(logreg, cv=5)
np_arr_train = train_df.to_numpy()
selector = logreg.fit(np_arr_train, labels)
y_pred = selector.predict(np_arr_train)
# Out:
# [1, 13, 14, 32]

# %%
confusion_matrix(labels_train, y_pred)
# Out:
# array([[60,  0],
#        [ 0,  9]])

# %%
y_prob = selector.predict_proba(np_arr_train)
y_class_prob = [x[1] for x in y_prob]

# %%
from sklearn.metrics import roc_auc_score, roc_curve, auc

fpr, tpr, threshold = roc_curve(labels_train, y_class_prob)
area = auc(fpr, tpr)
plt.plot(fpr, tpr, color='red', label='ROC' + str(area))
plt.plot([0, 1], [0, 1], linestyle='dotted')

# %%
logit = Logit(labels, np_arr_train)
print(logit.fit(method = 'lbfgs').summary())
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   69
# Model:                          Logit   Df Residuals:                       65
# Method:                           MLE   Df Model:                            3
# Date:                Thu, 25 Jun 2020   Pseudo R-squ.:                   1.000
# Time:                        01:58:32   Log-Likelihood:            -0.00013764
# converged:                       True   LL-Null:                       -26.718
# Covariance Type:            nonrobust   LLR p-value:                 1.481e-11
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           -15.9868   3513.284     -0.005      0.996   -6901.897    6869.923
# x2            15.8700   2475.198      0.006      0.995   -4835.429    4867.169
# x3            11.0576   2635.022      0.004      0.997   -5153.491    5175.606
# x4             1.5028   1838.585      0.001      0.999   -3602.057    3605.063
# ==============================================================================
#
# Complete Separation: The results show that there iscomplete separation.
# In this case the Maximum Likelihood Estimator does not exist and the parameters
# are not identified.

# %%
best_feature = [i for i, val in enumerate(split_score_track[int(index)][0]) if val]
best_l = index
final_df = pd.DataFrame()

labels_test=[]
for ind, path in enumerate(test_files):
    file = pd.read_csv(path, delimiter=',', skiprows = 5, names=Col)
    temp_dir = path.split('/')[-2]
    label = 0
    if 'bending' in temp_dir:
        label = 1
    df = split_data(int(best_l),file)
#   print(len(df_list))
    temp = []
    stat_row = stats(df)
    temp.append(stat_row)
    labels_test.append(label) 
    final_df = final_df.append(pd.DataFrame(temp))
test_df = final_df[best_feature]
test_df

np_arr_test = test_df.to_numpy()
selector.score(np_arr_test, labels_test)
# Out:
# 0.9473684210526315

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
x_train, y_train = smote.fit_resample(np_arr_train, labels_train)
logreg = LogisticRegression(solver='lbfgs')
model = logreg.fit(x_train, y_train)
model.score(x_train, y_train)
y_pred = model.predict(x_train)
model.score(np_arr_test, labels_test)
#len([i for i, val in enumerate(y_train) if val ])
# Out:
# 1.0

# %%
confusion_matrix(y_train, y_pred)
# Out:
# array([[60,  0],
#        [ 0, 60]])

# %%
y_prob = selector.predict_proba(x_train)
y_class_prob = [x[1] for x in y_prob]

fpr, tpr, threshold = roc_curve(y_train, y_class_prob)
area = auc(fpr, tpr)
plt.plot(fpr, tpr, color='red', label='ROC' + str(area))
plt.plot([0, 1], [0, 1], linestyle='dotted')

# %%
from sklearn.linear_model import LogisticRegressionCV

tmp_lbl = [i for i in range(1, 37)]
lambda_track={}
for l in range(1,21):
    final_df = pd.DataFrame()
    labels_tr=[]
    for index, path in enumerate(train_files):
        file = pd.read_csv(path, delimiter=',', skiprows = 5, names=Col)
        temp_dir = path.split('/')[-2]
        label = 0
        if 'bending' in temp_dir:
            label = 1
        df = split_data(l,file)
#         print(len(df_list))
        temp = []
        stat_row = stats(df)
        temp.append(stat_row)
        labels_tr.append(label)
# 
        final_df = final_df.append(pd.DataFrame(temp))
    #Cs=np.logspace(-1, 1, 100)
    logit = LogisticRegressionCV(cv = 5, penalty = 'l1', solver = 'liblinear', max_iter = 1000, Cs=np.logspace(-3, 3, 7))
    np_arr_tr = final_df.to_numpy()
    logit.fit(np_arr_tr, labels_tr)
    lambda_track[l] = [logit.C_[0], logit.score(np_arr_tr, labels_tr)]
#     print(l)
#     print(logit.score(np_arr_tr, labels_tr))
#     print(np.where(logit.C_ == logit.Cs_)[0][0])
# #     print(logit.Cs_)
    
#     print(logit.scores_)
lambda_track
# Out:
# {1: [0.1, 0.9710144927536232],
#  2: [1000.0, 1.0],
#  3: [10.0, 1.0],
#  4: [1.0, 1.0],
#  5: [1.0, 1.0],
#  6: [0.1, 0.9565217391304348],
#  7: [10.0, 1.0],
#  8: [10.0, 1.0],
#  9: [1.0, 1.0],
#  10: [1.0, 1.0],
#  11: [0.1, 0.9855072463768116],
#  12: [1.0, 1.0],
#  13: [10.0, 1.0],
#  14: [0.1, 0.9855072463768116],
#  15: [10.0, 1.0],
#  16: [1.0, 1.0],
#  17: [0.1, 0.9855072463768116],
#  18: [1.0, 1.0],
#  19: [0.1, 0.9855072463768116],
#  20: [100.0, 1.0]}

# %%
list_score = [lambda_track[x][1] for x in range(1, 21)]
#print(list_score)
best_l = np.argmax(list_score)+1
best_lambda = lambda_track[best_l][0]
##BEST (l,p)

(best_l, lamda)
#print(list_score)
# Out:
# (2, 10.0)

# %%
final_df = pd.DataFrame()
labels_tr=[]
for index, path in enumerate(train_files):
    file = pd.read_csv(path, delimiter=',', skiprows = 5, names=Col)
    temp_dir = path.split('/')[-2]
    label = 0
    if 'bending' in temp_dir:
        label = 1
    df = split_data(int(best_l),file)
#         print(len(df_list))
    temp = []
    stat_row = stats(df)
    temp.append(stat_row)
    labels_tr.append(label)
# 
    final_df = final_df.append(pd.DataFrame(temp))
#Cs=np.logspace(-1, 1, 100)
logit = LogisticRegressionCV(penalty = 'l1', solver = 'liblinear', max_iter = 1000, Cs=[lamda])
np_arr_tr = final_df.to_numpy()
logit.fit(np_arr_tr, labels_tr)
# Out:
# LogisticRegressionCV(Cs=[10.0], max_iter=1000, penalty='l1', solver='liblinear')

# %%
labels_test=[]
final_df = pd.DataFrame()
for ind, path in enumerate(test_files):
    file = pd.read_csv(path, delimiter=',', skiprows = 5, names=Col)
    temp_dir = path.split('/')[-2]
    label = 0
    if 'bending' in temp_dir:
        label = 1
    df = split_data(int(best_l),file)
#   print(len(df_list))
    temp = []
    stat_row = stats(df)
    temp.append(stat_row)
    labels_test.append(label) 
    final_df = final_df.append(pd.DataFrame(temp))
np_arr_test = final_df.to_numpy()
logit.score(np_arr_test, labels_test)
# Out:
# 1.0

# %%
lambda_track={}
for l in range(1,21):
    final_df = pd.DataFrame()
    labels_tr=[]
    for index, path in enumerate(train_files):
        file = pd.read_csv(path, delimiter=',', skiprows = 5, names=Col)
        temp_dir = path.split('/')[-2]
        label = temp_dir
        if 'bending' in temp_dir:
            label = 'bending'
        df = split_data(l,file)
#         print(len(df_list))
        temp = []
        stat_row = stats(df)
        temp.append(stat_row)
        labels_tr.append(label)
# 
        final_df = final_df.append(pd.DataFrame(temp))
    logit = LogisticRegressionCV(cv = 5, penalty = 'l1', solver = 'liblinear', max_iter = 1000, Cs=np.logspace(-3, 3, 7))
    np_arr_tr = final_df.to_numpy()
    logit.fit(np_arr_tr, labels_tr)
    lambda_track[l] = [logit.C_[0], logit.score(np_arr_tr, labels_tr)]
lambda_track
#labels_tr
# Out:
# {1: [0.1, 1.0],
#  2: [1.0, 1.0],
#  3: [10.0, 1.0],
#  4: [1.0, 1.0],
#  5: [1.0, 1.0],
#  6: [1.0, 1.0],
#  7: [0.1, 1.0],
#  8: [1000.0, 1.0],
#  9: [10.0, 0.8840579710144928],
#  10: [1.0, 1.0],
#  11: [0.1, 0.9855072463768116],
#  12: [10.0, 1.0],
#  13: [10.0, 1.0],
#  14: [0.1, 1.0],
#  15: [10.0, 1.0],
#  16: [100.0, 1.0],
#  17: [10.0, 1.0],
#  18: [0.1, 0.9855072463768116],
#  19: [0.1, 0.9855072463768116],
#  20: [0.1, 0.9855072463768116]}

# %%
final_df = pd.DataFrame()
labels_tr=[]
for index, path in enumerate(train_files):
    file = pd.read_csv(path, delimiter=',', skiprows = 5, names=Col)
    temp_dir = path.split('/')[-2]
    label = temp_dir
    if 'bending' in temp_dir:
        label = 'bending'
    df = split_data(int(1),file)
#         print(len(df_list))
    temp = []
    stat_row = stats(df)
    temp.append(stat_row)
    labels_tr.append(label)
# 
    final_df = final_df.append(pd.DataFrame(temp))
#Cs=np.logspace(-1, 1, 100)
logit = LogisticRegressionCV(penalty = 'l1', solver = 'liblinear', max_iter = 1000, Cs=[0.1])
np_arr_tr = final_df.to_numpy()
logit.fit(np_arr_tr, labels_tr)
# Out:
# LogisticRegressionCV(Cs=[0.1], max_iter=1000, penalty='l1', solver='liblinear')

# %%
labels_test=[]
final_df = pd.DataFrame()
for ind, path in enumerate(test_files):
    file = pd.read_csv(path, delimiter=',', skiprows = 5, names=Col)
    temp_dir = path.split('/')[-2]
    label = temp_dir
    if 'bending' in temp_dir:
        label = 'bending'
    df = split_data(int(1),file)
#   print(len(df_list))
    temp = []
    stat_row = stats(df)
    temp.append(stat_row)
    labels_test.append(label) 
    final_df = final_df.append(pd.DataFrame(temp))
np_arr_test = final_df.to_numpy()
logit.score(np_arr_test, labels_test)
# Out:
# 0.7894736842105263
